# %% [markdown]
# ## 3.0. Running this notebook
# We recommend running this notebook on a CUDA compatible local gpu. You can also run training on cpu, it will just take longer.
#
# You have three options for running this exercise on a GPU, choose one of them and start the exercise below in section "Imports":
# 1. Locally on your own GPU
# 2. On our dedicated compute cluster
# 3. On Google Colab
#
# We describe every option in more detail below:

# %%
# %pip install torch torchvision --extra-index-url https://download.pytorch.org/whl/cu113

# %% [markdown]
# ---
#
# ### Imports
#
# The following imports should work regardless of whether you are using Colab or local execution.

# %% [markdown]
# ### Imports
#
# The following imports should work regardless of whether you are using Colab or local execution.

# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import numpy as np
import matplotlib as plt
import k3d
import trimesh
import torch
import skimage
import sys

# %% [markdown]
# Use the next cell to test whether a GPU was detected by pytorch.

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## DeepSDF
#
#
# Here, we will take a look at 3D-reconstruction using [DeepSDF](https://arxiv.org/abs/1901.05103). We recommend reading the paper before attempting the exercise.
#
# DeepSDF is an auto-decoder based approach that learns a continuous SDF representation for a class of shapes. Once trained, it can be used for shape representation, interpolation and shape completion. We'll look at each of these
# applications.
#
# <img src="exercise_3/images/deepsdf_teaser.png" alt="deepsdf_teaser" style="width: 800px;"/>
#
# During training, the autodecoder optimizes both the network parameters and the latent codes representing each of the training shapes. Once trained, to reconstruct a shape given its SDF observations, a latent code is
# optimized keeping the network parameters fixed, such that the optimized latent code gives the lowest error with observed SDF values.
#
# An advantage that implicit representations have over voxel/grid based approaches is that they are not tied to a particular grid resolution, and can be evaluated at any resolution once trained.
#
# Similar to previous exercise, we'll first download the processed dataset, look at the implementation of the dataset, the model and the trainer, try out overfitting and generalization over the entire dataset, and finally inference on unseen samples.
#
# ### (a) Downloading the data
#
# Whereas volumetric models output entire 3d shape representations, implicit models like DeepSDF work on per point basis. The network takes in a 3D-coordinate (and additionally the latent vector) and outputs the SDF value at the queried point. To train such a model,
# we therefore need, for each of the training shapes, a bunch of points with their corresponding SDF values for supervision. Points are sampled more aggressively near the surface of the object as we want to capture a more detailed SDF near the surface. For those curious,
# data preparation is decribed in more detail in section 5 of the paper.
#
# We'll be using the ShapeNet Sofa class for the experiments in this exercise. We've already prepared this data, so that you don't need to deal with the preprocessing. For each shape, the following files are provided:
# - `mesh.obj` representing the mesh representation of the shape
# - `sdf.npz` file containing large number of points sampled on and around the mesh and their sdf values; contains numpy arrays under keys "pos" and "neg", containing points with positive and negative sdf values respectively
#
# ```
# # contents of exercise_3/data/<category>
# 1faa4c299b93a3e5593ebeeedbff73b/                    # shape 0
#     ├── mesh.obj                                    # shape 0 mesh
#     ├── sdf.npz                                     # shape 0 sdf
#     ├── surface.obj                                 # shape 0 surface
# 1fde48d83065ef5877a929f61fea4d0/                    # shape 1
# 1fe1411b6c8097acf008d8a3590fb522/                   # shape 2
# ```
# Download and extract the data with the code cell below.

# %% [markdown]
# ### (b) Dataset
#
# We provide a partial implementation of the dataset in `exercise_3/data/shape_implicit.py`.
# Your task is to complete the `#TODOs` so that the dataset works as specified by the docstrings.
#
# Once done, you can try running the following code blocks as sanity checks.

# %%
from exercise_3.data.shape_implicit import ShapeImplicit

num_points_to_samples = 80000
shape_class = "chair"

train_dataset = ShapeImplicit(shape_class,num_points_to_samples, "train")
val_dataset = ShapeImplicit(shape_class, num_points_to_samples, "val")
overfit_dataset = ShapeImplicit(shape_class, num_points_to_samples, "overfit")

# Get length, which is a call to __len__ function
print(f'Length of train set: {len(train_dataset)}')  
# Get length, which is a call to __len__ function
print(f'Length of val set: {len(val_dataset)}')  
# Get length, which is a call to __len__ function
print(f'Length of overfit set: {len(overfit_dataset)}')
# Out:
# Length of train set: 1389
# Length of val set: 155
# Length of overfit set: 1

# %% [markdown]
# Let's take a look at the points sampled for a particular shape.

# %%
gt_mesh = ShapeImplicit.get_mesh('/cluster/51/ataatasoy/project/data/chair/B01D7PG5EO', "chair")

# %%
# Out:
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07HSBRXD4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07TD47Y74.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B073P5L2S4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B079V7M9K4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07THSWCJ4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B071FMSMH4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07MF1S234.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B0746GYH54.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B073P1JP14.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075X4N4S4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07M7NSYC4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B073P1N4C4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07SSJDRL4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07JY4GZZ4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07HGKCRT4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QBMQQ34.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07Y5Y1264.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07TVJ1HL4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B78M4C4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B0831XKV24.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07JL5PT64.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07K7M4YT4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B4ZFR24.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B071J7Q9X4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075X52BH4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B073WHKXD4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B0732DWG74.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B01MXKMRK4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QHJZDH4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B01LP0UQX4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B4W5WJ4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07TWQSZL4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07P5LKZL4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QC8C7Y4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07HZ7PFW4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07DBFCXW4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B073P6FYT4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075X2XZF4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B00XBC3J84.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B085FJR494.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B7BDFQ4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07JX8K4W4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B086R33Q74.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B082L6R544.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07P5LN1M4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07JPGP464.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B085FHCKY4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QD6ZV84.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B4Z9Q24.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075X4VW74.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B079TXJTY4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07FK1HLZ4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075X1TB14.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B073P5QKL4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B073ZRNDP4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07K7K9224.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B00NO73Q84.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B0728NW8C4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B00I0VTOO4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075HRCG64.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07H8SM6Q4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075X543S4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07HSL66Q4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QGG6C74.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07NYSH2S4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QFP4ZG4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07HSKB7B4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07TFFF6V4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075HXHKZ4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B073P5V2P4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07DBGJ4X4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B01LR5SM74.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B073P19TL4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07P7NVGB4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B084T7K1P4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B072635HS4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07DB92LG4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07SRSJW74.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B4M38B4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QGFZ2B4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B073P12PK4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QW3JRT4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B082XLC9B4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07WQ4VQ74.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B4ZR624.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B4Z9BS4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075X3SHW4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07GSPVLZ4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07MNYTYR4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B072JC9KZ4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B4D4964.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B4ZL3T4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QSBZLW4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07P8STB84.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B082DMQ8L4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B074VMBGT4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QFRS7Y4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QNYVDH4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07G2HBKB4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07PC1FXK4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B00IIFW2L4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B8FHTJ4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B08568NJK4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B071J7Q3J4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B082Q97534.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B0727Q5F94.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07RQZKXT4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07R3CZMB4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07NZX6P34.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075X4VWP4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07ML7J584.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07MBFDL34.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07GFWLSS4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07P8STD74.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B073P6HGN4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07BL1NYC4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B072JC9KX4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QBRG2R4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B073NZWZ94.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07NPJB964.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B082VGM164.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B079KNLCX4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07JQKSDP4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075YQXRD4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07TYTPQ34.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07MJL66D4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07DBHB6D4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QF9Y234.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QBQFDP4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B088HFYZS4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B526F54.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B086JJQQZ4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B084DQ6BV4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07J29N3R4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075ZB5BR4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07HSMYP14.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07BWJD1V4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07TR68JS4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B01LONPUM4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07BZPL164.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B071FJR3T4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B082QD1HY4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07HSBJ1Q4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07MQD17G4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B0861T8Q44.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QGSZ564.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07JKJSTL4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QGWNTB4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07TP5LKB4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075X4JJX4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07MF1RR14.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B089LB2454.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B0725Z9MX4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07HSKY884.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QHKWJP4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075ZBW1S4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B08G1RYJ84.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B0871D75W4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075HXJ6P4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07Q88MYL4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B073P5QJ14.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07HSK7B24.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B072JC9844.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075X43FL4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07J2TW574.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B082VLTCM4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B0842LKSS4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07VNLB6Z4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07MKQT7V4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B86VTX4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QJ1WX64.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B4Z9Q14.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QGHTCY4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07121ZVX4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B4ZC524.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07HSJXG84.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07DMLG8Y4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B073NZSG24.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07V5WKJM4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B085FHGJT4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07BLB6644.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B0735VV8Z4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075ZDXBR4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075QDXWB4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075X2WP64.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07HSJXXZ4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B0853KT2J4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B071W5VJF4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QHJZ794.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075QDV244.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07SK9M5T4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B0725Z23G4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B4DB6Z4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07RPPBPV4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075YZ16V4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B071J4VYW4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07HZ77VP4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B4G5QD4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075YMJ254.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07WBYQQ84.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07H8PQFS4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QTK9ZJ4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B0853P1X94.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B073P6DSC4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B0824F6HZ4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B08GGSFH94.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B084T7ML94.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QHKQMY4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B073P13J54.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07VDD5HT4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B7B6W64.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07FFSKHK4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07S83QWR4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07HSK3534.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07MF1SRG4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075X61W74.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07JK86YC4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B4YC7P4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QHKV544.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075X33QV4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B4GQ964.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B4Z6JZ4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B0831X3864.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B4FZNM4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B4YQWZ4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B8P1J64.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B075X5HBD4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07DBDZ4R4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07JM1ZP24.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B084T7MQB4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07B7DKRW4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07QJ1X2J4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07MJL4S24.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07P7NTK44.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B078JH73F4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B07DVTZLR4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/4/B071FMSMD4.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/I/B01LP0VBDI.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/I/B01GGKYUKI.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/I/B01M4OYBOI.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/I/B00TOAN83I.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/I/B01LR5SIRI.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/I/B00TOAN7YI.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/A/B01N6AQX0A.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/A/B01D3C7Z4A.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/A/B01LR5SAIA.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/A/B00NUS5GXA.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/A/B01E3R7GWA.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/A/B00TS18AEA.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/A/B00F5CKWBA.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/A/B002CM3J2A.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/A/B01IJ5A2UA.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/A/B01DA8LC0A.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/A/B00DIHVMEA.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/A/B01LR5S1WA.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075HRFFQ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B082QCPWG3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HZ7X963.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07H8SZNZ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HSHS163.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B086B5P473.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07MBFDJQ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0725Z9MX3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HGGPCW3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QGWNJB3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07P5LM5D3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07MJL4ZQ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B072JC6WL3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07VQSWN33.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QGG3MR3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07S4CCML3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07DBDZMX3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B078JGHZT3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4M6933.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4ZQQL3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HZ9K9S3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07P5LMCZ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4WH5K3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HSMMGF3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07DMJN8H3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B082VMJ233.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075X4F5C3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073G947W3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QHL2CX3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B083YG3JN3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07BWMSQC3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07SRSJ5G3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07H8JNCF3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07Q9CS6C3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07W5BDJ73.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4XK5V3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075X4VWS3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07GFFKVG3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B082QCQ723.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4WKMZ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075X61W33.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B082PCMFY3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0824FBQF3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07SMJZKQ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07JGXXK33.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B084HVB133.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B072FVHS93.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0732HD6Y3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07JGPKYD3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B071J7Q343.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B082MY2MX3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07DBG2663.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075Z96L53.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4SF2F3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4D48S3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07F3XM8M3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07DBFQV23.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07K8V2SX3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B8NZQF3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QD9BLP3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HZ57QD3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07RMYJYM3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07G33RYW3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07TP5MKP3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075YQ8QT3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07PBZ3VJ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4L9BQ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B8K1DL3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075X4QMX3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073P1H5W3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07RT5JN33.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07CB54MM3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07M7NSYD3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07BW8QSD3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07MJL48M3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B086JJQQZ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07374QFJ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07JGZP163.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B085FJWNC3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075YLG173.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07RPPBNQ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07JLGCLV3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07BW8MJJ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07J2YWSF3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07JD47LW3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07MF1RKM3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B079TXJCP3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4W31C3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B071ZJ6CK3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07MJL5SY3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075YLQTJ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075X4VM73.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B084HV7BC3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QBMQ4K3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HSF7N83.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B082VLYF53.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0732DWG63.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4MN2R3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073P23TT3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07MCBKT23.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QBMQPH3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07BWJCVK3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075X2LLX3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B084MXWPF3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QBMQ543.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QHKWJS3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075YLKDM3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07K7NSKQ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B7GV4P3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075X4F593.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073NZGLK3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07TKY5163.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073P15SD3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075HXLWS3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073P5KYG3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073P1TPM3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07JM6HFW3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B071SLGYB3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QJXMX23.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B072PZC1L3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07G2FP3M3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0824FH9M3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4YHFR3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073G856G3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0728KSP33.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07Q3WM673.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07GG1Z4J3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07DT4GYP3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B78G443.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0732D26C3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07MHMJD43.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07K7NQR23.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075NNM243.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QFP4M23.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4D4F83.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07BWK59J3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07JQX8WF3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4ML473.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07JM1QT63.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07TYTR8M3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07MBFDRZ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07P5LLX43.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0853KM5Q3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4YY8H3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07JKTRKT3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07C8DHX43.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07Y2BTPJ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B072FVHRZ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4ZVLC3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B085FGSHR3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075Z6SHD3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B084HV5LK3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4GVRM3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B078JHPRZ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07ZT3QBG3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07RTZ5493.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B072LXZ653.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B082JJJKT3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0853Q3Z93.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073P66TV3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QF8RBJ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0857JM2Q3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QBQD983.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4YXNR3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07JKJKH43.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0857JWY13.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07VRWM773.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0735W9DK3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4ZFD13.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0831Q5ZW3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4G5ZL3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07D4BD5D3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07G2RHL73.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07SY36LZ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QGG3MS3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07VB3TJF3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073P5QJ53.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073P1LP93.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07XGQ9RM3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HSF22L3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07JL5Q123.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4MQRH3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07Q3Y23R3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07JX7P4L3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QHYF1L3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073P5V2P3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073P13J43.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07DBF3V83.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HZ65PW3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0732KBBJ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QCQ35J3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075HX4D73.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073P5MPW3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4MCSF3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073P1HYG3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HZ1L353.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0853NYVZ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HZ65Q43.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07YLZS7P3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07PBZBF73.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0853VPXF3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07TXPYH43.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073NZT573.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0735VGDT3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4Z7MP3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07K7K5NX3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B074VLPC13.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07DBGJ4K3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0719FLQP3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4Z7WB3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B082VSXML3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075Y184L3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073P1H5Z3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075YNL7R3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07BWK42J3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07WQ4P373.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075YMN1T3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07L6LL293.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QFRSC83.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07VSV4783.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QGG5NC3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07JPGP3X3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B071777YN3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07DBCMTD3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073P1HRN3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B076YRSWH3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QGG5263.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073P19B53.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HSLTFY3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B87J7L3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07DBGCP63.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0723H8HN3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075YN3HB3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073P51233.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4SCB53.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07PC5G5D3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07YBH2SR3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B072PZJZY3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4SDVG3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07BWMQQB3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0828F9CR3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B072ZMVR53.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HGKZFG3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B082VML3Q3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HSMN673.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075YP3C53.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07JQX8SD3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QB8JRC3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HSHTN13.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HSF53Y3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QBMQMN3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HKCJPJ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B076VG6LF3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07MQD2113.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HSN8783.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075YP3BY3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073P1LM83.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073G7BV63.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075YNL763.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4ZPGY3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B074DZ65J3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07HSL7553.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07K4ZCQC3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075Z96KX3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B0853MY3J3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B4CXSF3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07B7N6JH3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07FFVJN43.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QFRSC43.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B082Q8NLZ3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B071W5VJ93.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B073P5Y9K3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QC8B6R3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07QB8K1B3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07M6PKCM3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075HWK9M3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B07TN1PGY3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/3/B075Z6SHL3.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07HZ61DWG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07J2W39LG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B071ZJ6CDG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07C9W437G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B075X4PTBG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07F9X919G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07G2X9ZCG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07BWLJNRG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B073P1BJ2G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B073P23TMG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B084XMQK3G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B078JGYJTG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07QC8B6TG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07VZF5L4G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B4Z9Q3G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07HSJSH7G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07QFP4PYG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B0828FFDWG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B072C8Q4SG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07QBQD99G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07QFP52NG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B075YLKDPG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B01LP0UX9G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07JJ9FB4G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07DYJPF4G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07DBHPK4G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B4ZQXDG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B0825CXG9G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07TN2RRDG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B071W5V76G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B073P6KMTG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07DBDRHXG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B075X4J15G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B071SHHZVG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B0825CP44G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B079VNL3CG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07MCCRP2G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07QFRS89G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07JY3BQNG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B073GC43LG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07HSJJDWG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B082XLFFCG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07QHYDDZG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07QFP4ZRG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B073P46SHG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B7MWMCG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B0856G51ZG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B073P5SYYG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07JGMW8DG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07HPQYW7G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B018K6NSIG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B084W32QRG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07JKJSRQG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B883YXG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07Y3QM2SG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B4W1YCG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07QGWNJFG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B085GXS8JG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07QGSZ78G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07DB92GZG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B075X4PT3G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B075YLKB9G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07QHL6SYG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07TZ9BMJG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07WTFJGRG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B075YNL75G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07HPDV36G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07QHL5CYG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B073P6HGSG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07HSJX4TG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B084W2DDSG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B085FH8JFG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B4MJKPG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07HSNFJNG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B0732L974G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07JKJSJ8G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B075X65QYG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B00R3MZITG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B076V4XHNG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B4ZBPJG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B4MRPTG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07ML7P94G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B073P17T6G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B075HRFFTG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B072FVHS9G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B4MRKQG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B075HR7LJG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07DBDT6YG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B4SC7DG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07QGSZ38G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B073P58BZG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07ZVLRCSG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B4SMR2G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B4SDX5G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07DBDV64G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B084W2X98G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B082VLR43G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B0842H7CKG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B071ZJ6BGG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B082VMWB4G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B075X43FMG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B082JH9VWG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07RQMSP2G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B8NW6GG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B082XD1PKG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B073P5C7JG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07DBB7H9G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B0824FB4VG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B084L7SNDG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07TTYD8YG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07JLSSYTG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B075X2WNWG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07GNCVKSG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B075ZCLPVG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07QDNRFKG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B082XLMW6G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B084T7TZDG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B074DZGRMG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B4M2N7G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07HZ58Q4G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B084HTY39G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B078JG4N1G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B075HXPFTG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07SYL1X9G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07DBGPVLG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B073P1H6CG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07P64ZJQG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B075X4VWHG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B073P117DG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07QJ23JZG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07F2M2VGG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07JV99PSG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B071LTB14G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07L6KM74G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B4ZPCXG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07JLZC56G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B074KKMQBG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B084T7NZNG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B8JXP8G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07847Y5BG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07HSLKKXG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B073P5PZ5G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07DBDZ4SG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B0732KDJ4G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B084KD1LWG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B082VMZGDG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B4MD59G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B074KK384G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07P8STHZG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B086VNNCNG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B082XMRGZG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B0853KX8NG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07DBFT2YG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07PNHSR4G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B071ZLY13G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B4MPVZG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B082VMDZKG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B51N75G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07J2KGD9G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B009S7IZWG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07MPFZPRG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B073P18X3G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B82T39G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B075X4VW5G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07G2RG94G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07Q2MHJCG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07MND862G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B073P5Y9MG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07PC1PDXG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B0716YRXBG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07BWK59RG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07DBG898G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07K7TRF3G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07JKJP7QG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B082Q97X1G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B4GXYDG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07B7DFM2G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07GFFPKBG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07SZ1PZ1G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B0853N7D4G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07ML7NZQG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07TYTP8SG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B082Q8WR7G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B0828DRFTG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B073P66TYG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B071ZJ6C8G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07HKGY6CG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07HZ4NG1G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B08DW41H2G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B075Z9Z16G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07WGNT4GG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B0824FJCWG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07HSF6Z8G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B00X4SCCFG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B01DN7NFRG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B01LP0VI3G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07HK3F2GG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B0735T68YG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07MJL48NG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07DBD9W9G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B073P5L2TG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07BW8VJ5G.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B01LONQBDG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07SHYNBDG.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/G/B07DBJLZ6G.glb
# ...
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0732HV63M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0735T9WPM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B083YFR99M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07GFLG5MM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B082JHJKGM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07JK89F5M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07C8WMTZM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B071SHLFLM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B4G612M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07DBK7NFM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B01DA8QZFM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0871DD1NM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073P36T7M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07TZMWH8M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0725Z9MXM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QCQ1J5M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B01GGKYZQM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073P6BG6M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07JY3QG6M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07BWLMJJM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B08568W87M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B084DQ9VWM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QFP5TNM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B08568HG2M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073751DMM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QC9YBPM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07JVP2C7M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07ML7J57M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QGSZ31M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075YPTF9M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0723H8HLM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B079V329QM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07HSK7YBM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07K7K25NM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07MF1S4YM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B082DPT2QM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B072JG3W4M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B084W2RX9M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B4L589M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B071J7Q9WM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07MQD17DM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07HK6N3JM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07LFP96JM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B079VNL3GM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B076V9V7DM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073P1F2HM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07PGK6H8M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075X4F5LM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0857K54FM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07TF7XYXM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07GFVJWNM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QDNRB9M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B077X5Y6GM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QHL15NM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B071J7Q3JM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B4WH6NM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073P1HZQM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075HXLWRM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07DB95WHM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B4MH91M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QD6Z8SM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07BWMSP5M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07YBHC89M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QD6V13M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07HZ1LXVM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B072ZRPFNM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B4MKCLM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075X4HZQM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B7H9VMM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073P5KYCM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B084T7GSXM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B082QDLG2M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0825DG9NM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07MBFDWNM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0723DG6CM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B083YFQPPM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07HSK7Y5M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07Q5ZVTGM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B4W2ZFM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B085FJPW9M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QBB4WRM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QHYD94M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07HKGKSMM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07JQX8F3M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07J55BLDM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B084XMW9JM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QWZDNLM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QGG524M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07VLFWFQM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075Z8HXFM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B4L563M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0735T7KTM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07JLSNT7M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07263589M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075QDMWTM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073P5QKCM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075ZBW1QM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073P1LPPM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07GFRR62M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B072C5WP1M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073P5DMVM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07HSJY1JM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07GZY278M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07W422B7M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B082QD6R9M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B072PZC1PM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QB8JPXM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B8NBQWM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07GDYVV9M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07JL5Q2PM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07C8MT64M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075X2FZSM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075X4N3FM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07GFG6JMM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QGG5LLM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075QL8KCM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07VDD538M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07HZ73SBM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07RHB221M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07R3TWDTM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07CB5GT3M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B082VFPPJM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07HSBD8DM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QTD9VPM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073P6LBFM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07GFWF2GM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B072ZLCB3M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073P6HGVM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075X4N3GM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07P7NX68M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0735CJJDM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0825DHHVM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QC8B1VM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07SH7L5QM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07TBGH48M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B7J8J9M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07374SBFM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QGFYLLM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07RF89SQM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073P5FLXM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07BWMQLWM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075YMXWZM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B7B1HCM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QGFZWRM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073NZGLGM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0825CLV7M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07HPGHMHM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075YLTF2M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B079LFHQPM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07JYN8DBM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QCMB9XM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0853N8T7M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07JL5PRQM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B078JK89KM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QNWMF2M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07HZ72LZM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QFP52JM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B8WZQMM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B06WVPB4TM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B084MYDTKM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07YNFQCWM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07MF1TDMM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075X4F5NM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07Q5ZXRCM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07DBG898M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B071FMSY5M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B4MD55M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07TS7ZCVM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0871DCNRM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07Y3PH5YM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073NZPPRM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07K7NXWXM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07Y33KVDM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07HZ8J1WM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B4SDLJM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0735W9DMM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07DB8XFGM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0824FS7PM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QFP5Y7M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B017DORX3M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QBQF5CM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07VST5VVM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B082BL8QJM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073G947XM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B4SCPNM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B082XCMRSM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073P13Q7M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07MCBKT3M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07DBDX23M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075YM7Q9M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07HSCN9RM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07HSCJZQM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075X65R5M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B01DJH742M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07JKJKDKM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075X4R4LM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075X4YDCM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075YPTG6M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B085559VGM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B4ZKG1M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075HWDTMM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0732FTB7M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07MHMGJMM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07WGNQVGM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07MFYVLJM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0746H4BPM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B7J3B5M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07SX37TCM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07F3W4QWM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07BBWMPJM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B7DKRVM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QDL48XM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07DBGJ5PM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075X2LLTM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07BWLJR3M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B82PXCM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07HSK2H7M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07N6RT9SM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073G6T3GM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B01GGKYT7M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07KXFJ12M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07HSGPJLM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075YQXRJM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B074KLFZRM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073P5XJFM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QBMQC7M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07K7LVRSM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0735S6CYM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B4MDHXM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07PBZ3VCM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07JKJSLWM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QDNT1MM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QC8CFBM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B076HDDMKM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073P5L2QM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B4P1X7M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B0814T6G5M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B075YLVQ7M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07H8K1FDM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QFRT4NM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B5126ZM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B073P17RRM.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07YM1FJ1M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07SJ75Y1M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07QFRSC8M.glb
# /cluster/51/ataatasoy/abo_dst/3dmodels/original/M/B07B4W2MFM.glb

# %%
from exercise_3.util.visualization import visualize_mesh, visualize_pointcloud

shape_id = train_dataset[124]['name'] 
points = train_dataset[124]['points']
sdf = train_dataset[124]['sdf']

# sampled points inside the shape
inside_points = points[sdf[:, 0] < 0, :].numpy()

# sampled points outside the shape
outside_points = points[sdf[:, 0] > 0, :].numpy()
print(outside_points.dtype)
# Out:
# float32

# %%
mesh = ShapeImplicit.get_mesh(shape_id, shape_class)
print('Mesh')
visualize_mesh(mesh.vertices, mesh.faces, flip_axes=True)
# Out:
# Mesh
# Output()

# %%
print('Sampled points with negative SDF (inside)')
visualize_pointcloud(inside_points, 0.025, flip_axes=True)
# Out:
# Sampled points with negative SDF (inside)
# Output()

# %%
print('Sampled points with positive SDF (outside)')
visualize_pointcloud(outside_points, 0.025, flip_axes=True)
# Out:
# Sampled points with positive SDF (outside)
# Output()

# %% [markdown]
# You'll notice that more points are sampled close to the surface rather than away from the surface.

# %% [markdown]
# ### (c) Model
#
# The DeepSDF auto-decoder architecture is visualized below:
#
# <img src="exercise_3/images/deepsdf_architecture.png" alt="deepsdf_arch" style="width: 640px;"/>
#
# Things to note:
#
# - The network takes in the latent code for a shape concatenated with the query 3d coordinate, making up a 259 length vector (assuming latent code length is 256).
# - The network consist of a sequence of weight-normed linear layers, each followed by a ReLU and a dropout. For weight norming a layer, check out `torch.nn.utils.weight_norm`. Each of these linear layers outputs a 512 dimensional vector, except the 4th layer which outputs a 253 dimensional vector.
# - The output of the 4th layer is concatenated with the input, making the input to the 5th layer a 512 dimensional vector.
# - The final layer is a simple linear layer without any norm, dropout or non-linearity, with a single dimensional output representing the SDF value.
#
# Implement this architecture in file `exercise_3/model/deepsdf.py`.
#
# Here are some basic sanity tests once you're done with your implementation.

# %%
from exercise_3.model.deepsdf import DeepSDFDecoder
from exercise_3.util.model import summarize_model

deepsdf = DeepSDFDecoder(latent_size=256)
print(summarize_model(deepsdf))

# input to the network is a concatenation of point coordinates (3) and the latent code (256 in this example);
# here we use a batch of 4096 points
input_tensor = torch.randn(4096, 3 + 256)
predictions = deepsdf(input_tensor)

print('\nOutput tensor shape: ', predictions.shape)  # expected output: 4096, 1

num_trainable_params = sum(p.numel() for p in deepsdf.parameters() if p.requires_grad) / 1e6
print(f'\nNumber of traininable params: {num_trainable_params:.2f}M')  # expected output: ~1.8M
# Out:
#    | Name  | Type           | Params
# -------------------------------------------
# 0  | lin0  | Linear         | 133632
# 1  | relu0 | ReLU           | 0
# 2  | drop0 | Dropout        | 0
# 3  | lin1  | Linear         | 263168
# 4  | relu1 | ReLU           | 0
# 5  | drop1 | Dropout        | 0
# 6  | lin2  | Linear         | 263168
# 7  | relu2 | ReLU           | 0
# 8  | drop2 | Dropout        | 0
# 9  | lin3  | Linear         | 263168
# 10 | relu3 | ReLU           | 0
# 11 | drop3 | Dropout        | 0
# 12 | lin4  | Linear         | 130042
# 13 | relu4 | ReLU           | 0
# 14 | drop4 | Dropout        | 0
# 15 | lin5  | Linear         | 263168
# 16 | relu5 | ReLU           | 0
# 17 | drop5 | Dropout        | 0
# 18 | lin6  | Linear         | 263168
# 19 | relu6 | ReLU           | 0
# 20 | drop6 | Dropout        | 0
# 21 | lin7  | Linear         | 263168
# 22 | relu7 | ReLU           | 0
# 23 | drop7 | Dropout        | 0
# 24 | lin8  | Linear         | 514
# 25 | TOTAL | DeepSDFDecoder | 1843196
#
# Output tensor shape:  torch.Size([4096, 1])
#
# Number of traininable params: 1.84M
# /workspace/.venv/lib/python3.8/site-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")

# %% [markdown]
# ### (d) Training script and overfitting to a single shape
#
# Fill in the train script in `exercise_3/training/train_deepsdf.py`, and verify that your training work by overfitting to a few samples below.

# %%
from exercise_3.training import train_deepsdf

overfit_config = {
    'experiment_name': '3_2_deepsdf_overfit',
    'device': 'cuda:0',  # change this to cpu if you do not have a GPU
    'is_overfit': True,
    'num_sample_points': 4096,
    'latent_code_length': 256,
    'batch_size': 1,
    'resume_ckpt': None,
    'learning_rate_model': 0.0005,
    'learning_rate_code': 0.001,
    'lambda_code_regularization': 0.0001,
    'max_epochs': 200,
    'print_every_n': 50,
    'visualize_every_n': 250,
    'shape_class': shape_class
}

train_deepsdf.main(overfit_config)  # expected loss around 0.0062

# %% [markdown]
# Let's visualize the overfitted shape reconstruction to check if it looks reasonable.

# %%
# Load and visualize GT mesh of the overfit sample
gt_mesh = ShapeImplicit.get_mesh('7e728818848f191bee7d178666aae23d')
print('GT')
visualize_mesh(gt_mesh.vertices, gt_mesh.faces, flip_axes=True)

# Load and visualize reconstructed overfit sample; it's okay if they don't look visually exact, since we don't run 
# the training too long and have a learning rate decay while training 
mesh_path = "exercise_3/runs/3_2_deepsdf_overfit/meshes/01999_000.obj"
overfit_output = trimesh.load(mesh_path)
print('Overfit')
visualize_mesh(overfit_output.vertices, overfit_output.faces, flip_axes=True)

# %% [markdown]
# ### (e) Training over entire train set
#
# Once overfitting works, we can train on the entire train set.
#
# Note: This training will take a few hours on a GPU (took ~3 hrs for 500 epochs on our 2080Ti, which already gave decent results). Please make sure to start training early enough before the submission deadline.

# %%
# Set the Experiment name

experiment_name = 'bed_generalization'

# %%
from exercise_3.training import train_deepsdf


generalization_config = {
    'experiment_name': experiment_name,
    'device': 'cuda:0',  # run this on a gpu for a reasonable training time
    'is_overfit': False,
    'num_sample_points': 4096, # you can adjust this such that the model fits on your gpu
    'latent_code_length': 256,
    'batch_size': 1,
    'resume_ckpt': None,
    'learning_rate_model': 0.0005,
    'learning_rate_code': 0.001,
    'lambda_code_regularization': 0.0001,
    'max_epochs': 500,  # not necessary to run for 2000 epochs if you're short on time, at 500 epochs you should start to see reasonable results
    'print_every_n': 50,
    'visualize_every_n': 5000,
    'shape_class': shape_class
}

train_deepsdf.main(generalization_config)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 19
#       1 from exercise_3.training import train_deepsdf
#       3 experiment_name = 'bed_generalization'
#       5 generalization_config = {
#       6     'experiment_name': experiment_name,
#       7     'device': 'cuda:0',  # run this on a gpu for a reasonable training time
#       8     'is_overfit': False,
#       9     'num_sample_points': 4096, # you can adjust this such that the model fits on your gpu
#      10     'latent_code_length': 256,
#      11     'batch_size': 1,
#      12     'resume_ckpt': None,
#      13     'learning_rate_model': 0.0005,
#      14     'learning_rate_code': 0.001,
#      15     'lambda_code_regularization': 0.0001,
#      16     'max_epochs': 500,  # not necessary to run for 2000 epochs if you're short on time, at 500 epochs you should start to see reasonable results
#      17     'print_every_n': 50,
#      18     'visualize_every_n': 5000,
# ---> 19     'shape_class': shape_class
#      20 }
#      22 train_deepsdf.main(generalization_config)
#
# NameError: name 'shape_class' is not defined

# %% [markdown]
# ### (f) Inference using the trained model on observed SDF values
#
# Fill in the inference script `exercise_3/inference/infer_deepsdf.py`. Note that it's not simply a forward pass, but an optimization of the latent code such that we have lowest error on observed SDF values.

# %%
from exercise_3.inference.infer_deepsdf import InferenceHandlerDeepSDF

device = torch.device('cuda:0')  # change this to cpu if you're not using a gpu

inference_handler = InferenceHandlerDeepSDF(256, f'exercise_3/runs/{experiment_name}', device)

# %% [markdown]
# First, we try inference on a shape from validation set, for which we have a complete observation of sdf values. This is an easier problem as compared to shape completion,
# since we have all the information already in the input.
#
# Let's visualize the observations.

# %%
# get observed data
points, sdf = ShapeImplicit.get_all_sdf_samples("90ed47303b284a8e8bd3a6724eacfb54", "bed")

inside_points = points[sdf[:, 0] < 0, :].numpy()
outside_points = points[sdf[:, 0] > 0, :].numpy()

# visualize observed points; you'll observe that the observations are very complete
print('Observations with negative SDF (inside)')
visualize_pointcloud(inside_points, 0.025, flip_axes=True)
print('Observations with positive SDF (outside)')
visualize_pointcloud(outside_points, 0.025, flip_axes=True)
# Out:
# Observations with negative SDF (inside)
# Output()
# Observations with positive SDF (outside)
# Output()

# %% [markdown]
# Reconstruction on these observations with the trained model:

# %%
# reconstruct
vertices, faces = inference_handler.reconstruct(points, sdf, 800)
# visualize
visualize_mesh(vertices, faces, flip_axes=True)
# Out:
# /workspace/.venv/lib/python3.8/site-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# [00000] optim_loss: 0.002050
# [00050] optim_loss: 0.001996
# [00100] optim_loss: 0.002001
# [00150] optim_loss: 0.001963
# [00200] optim_loss: 0.001993
# [00250] optim_loss: 0.002037
# [00300] optim_loss: 0.001949
# [00350] optim_loss: 0.001956
# [00400] optim_loss: 0.001982
# [00450] optim_loss: 0.002008
# [00500] optim_loss: 0.001997
# [00550] optim_loss: 0.001988
# [00600] optim_loss: 0.001971
# [00650] optim_loss: 0.002001
# [00700] optim_loss: 0.001983
# [00750] optim_loss: 0.001992
# Optimization complete.
# Output()

# %% [markdown]
# Next, we can try the shape completion task, i.e., inference on a shape from validation set, for which we do not have a complete observation of sdf values. The observed points are visualized below:

# %%
# get observed data
points, sdf = ShapeImplicit.get_all_sdf_samples("b351e06f5826444c19fb4103277a6b93_incomplete")

inside_points = points[sdf[:, 0] < 0, :].numpy()
outside_points = points[sdf[:, 0] > 0, :].numpy()

# visualize observed points; you'll observe that the observations are incomplete
# making this is a shape completion task
print('Observations with negative SDF (inside)')
visualize_pointcloud(inside_points, 0.025, flip_axes=True)
print('Observations with positive SDF (outside)')
visualize_pointcloud(outside_points, 0.025, flip_axes=True)

# %% [markdown]
# Shape completion using the trained model:

# %%
# reconstruct
vertices, faces = inference_handler.reconstruct(points, sdf, 800)
# visualize
visualize_mesh(vertices, faces, flip_axes=True)

# %% [markdown]
# ### (g) Latent space interpolation
#
# The latent space learned by DeepSDF is interpolatable, meaning that decoding latent codes from this space produced meaningful shapes. Given two latent codes, a linearly interpolatable latent space will decode
# each of the intermediate codes to some valid shape. Let's see if this holds for our trained model.
#
# We'll pick two shapes from the train set as visualized below.

# %%
from exercise_3.data.shape_implicit import ShapeImplicit
from exercise_3.util.visualization import visualize_mesh

mesh = ShapeImplicit.get_mesh("494fe53da65650b8c358765b76c296")
print('GT Shape A')
visualize_mesh(mesh.vertices, mesh.faces, flip_axes=True)

mesh = ShapeImplicit.get_mesh("5ca1ef55ff5f68501921e7a85cf9da35")
print('GT Shape B')
visualize_mesh(mesh.vertices, mesh.faces, flip_axes=True)

# %% [markdown]
# Implement the missing parts in `exercise_3/inference/infer_deepsdf.py` such that it interpolates two given latent vectors, and run the code fragement below once done.

# %%
from exercise_3.inference.infer_deepsdf import InferenceHandlerDeepSDF

inference_handler = InferenceHandlerDeepSDF(256, "exercise_3/runs/3_2_deepsdf_generalization", torch.device('cuda:0'))
# interpolate; also exports interpolated meshes to disk
inference_handler.interpolate('494fe53da65650b8c358765b76c296', '5ca1ef55ff5f68501921e7a85cf9da35', 60)

# %% [markdown]
# Visualize the interpolation below. If everything works out correctly, you should see a smooth transformation between the shapes, with all intermediate shapes being valid sofas.

# %%
# https://www.moodle.tum.de/mod/forum/discuss.php?d=464795
import os

os.environ["PYOPENGL_PLATFORM"] = "egl"

# %%
from exercise_3.util.mesh_collection_to_gif import  meshes_to_gif
from exercise_3.util.misc import show_gif

# create list of meshes (just exported) to be visualized
mesh_paths = sorted([x for x in Path("exercise_3/runs/3_2_deepsdf_generalization/interpolation").iterdir() if int(x.name.split('.')[0].split("_")[1]) == 0], key=lambda x: int(x.name.split('.')[0].split("_")[0]))
mesh_paths = mesh_paths + mesh_paths[::-1]

# create a visualization of the interpolation process
meshes_to_gif(mesh_paths, "exercise_3/runs/3_2_deepsdf_generalization/latent_interp.gif", 20)
show_gif("exercise_3/runs/3_2_deepsdf_generalization/latent_interp.gif")

# %% [markdown]
# ## Submission
#
# This is the end of exercise 3 🙂. Please create a zip containing all files we provided, everything you modified, your visualization images/gif (no need to submit generated OBJs), including your checkpoints. Name it with your matriculation number(s) as described in exercise 1. Make sure this notebook can be run without problems. Then, submit via Moodle.
#
# **Note**: The maximum submission file size limit for Moodle is 100M. You do not need to submit your overfitting checkpoints; however, the generalization checkpoint will be >200M. The easiest way to still be able to submit that one is to split it with zip like this: `zip -s 100M model_best.ckpt.zip model_best.ckpt` which creates a `.zip` and a `.z01`. You can then submit both files alongside another zip containing all your code and outputs.
#
# **Submission Deadline**: 22.12.2023, 23:55

# %% [markdown]
# ## References
#
# [1] Dai, Angela, Charles Ruizhongtai Qi, and Matthias Nießner. "Shape completion using 3d-encoder-predictor cnns and shape synthesis." Proceedings of the IEEE Conference on Computer Vision and Pattern Recognition. 2017.
#
# [2] Park, Jeong Joon, et al. "Deepsdf: Learning continuous signed distance functions for shape representation." Proceedings of the IEEE/CVF Conference on Computer Vision and Pattern Recognition. 2019.
